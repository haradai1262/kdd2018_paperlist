# %%
import requests
from bs4 import BeautifulSoup

# %%
papers = {}

target_url = 'http://www.kdd.org/kdd2018/accepted-papers'
r = requests.get(target_url)
soup = BeautifulSoup(r.text, 'lxml')
for i, item in enumerate( soup.select('a[href^="http://www.kdd.org/kdd2018/accepted-papers/view/"]') ):
    if i % 20 == 0: print( i )
    title = item.get_text()
    url = item.get('href')
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    s = soup.find('div', {'class': 'g-mb-60'})

    author = s.find('h6').get_text()
    author_list = [ n.strip() for n in author.split(';')]
    abst = s.find('p').get_text()
    try:
        yid = s.find('iframe').attrs['src'].split('/')[-1]
    except:
        yid = 'None'
    try:
        pdf = s.find('a').attrs['href']
    except:
        pdf = 'None'
    
    paper = {}
    paper['title'] = title
    paper['author'] = author_list
    paper['abst'] = abst
    paper['yid'] = yid
    paper['pdf'] = pdf
    papers[i] = paper
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280

# %%
def get_texts_from_papers( papers ):
    Texts = []
    for paper in papers.values():
        text = paper['title'] + ' ' + paper['abst']
        text = text.lower()
        Texts.append( text )
    return Texts

def get_BoWs_from_english_rawtext( texts_tmp, pos_filter ):
    BoWs_tmp = []
    for text in texts_tmp:
        tokens = get_tokens( text, pos_filter )
        BoWs_tmp.append( tokens )
    return BoWs_tmp

from nltk import word_tokenize, pos_tag
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def get_tokens( text, pos_filter ):
    tokens = []
    words = word_tokenize( text )
    words = list(map(stemmer.stem, words))
    for token in pos_tag( words ):
        if token[1] in pos_filter:
            tokens.append( token[0] )
    return tokens

import gensim
from gensim import corpora, models, similarities

def get_tfidf( BoWs_tmp ):
    dictionary = corpora.Dictionary( BoWs_tmp )
    dictionary.filter_extremes(no_below=2, no_above=0.5 )
    corpus = [dictionary.doc2bow(text) for text in BoWs_tmp]
    tfidf = models.TfidfModel(corpus)
    return corpus, dictionary, tfidf

def get_tfidf_each_document( Corpus, Dictionary, Tfidf ):
    TfidfScores = {}
    docNum = len( Corpus )
    for i in range( docNum ):
        tfidfScore = {}
        tfidfCorpus = [ Tfidf[c] for c in Corpus ]
        for j, wc in enumerate( sorted( tfidfCorpus[i], key=lambda x:x[1], reverse=True ) ):
            tfidfScore[ Dictionary[wc[0]] ] = wc[1]
        TfidfScores[i] = tfidfScore
    return TfidfScores

def get_tfidf_each_word( TfidfScores ):
    wordTfidf = {}
    for tfidf_score in TfidfScores.values():
        for w, score in tfidf_score.items():
            if w in wordTfidf:
                wordTfidf[w] += score
            else:
                wordTfidf[w] = score
    return wordTfidf

def get_keywords( TfidfEachWord, topN ):
    n = 0
    for w, score in sorted( TfidfEachWord.items(), key=lambda x:x[1], reverse=True):
        if n >= topN: continue
        n += 1
        print( '   %.3f %s' % ( score, w) )

def get_keywords_each_document( TfidfScores, topN ):
    for i, tfidfScore in TfidfScores.items():
        print( i, papers[i]['title'] )
        n = 0
        for w, score in sorted( tfidfScore.items(), key=lambda x:x[1], reverse=True):
            if n >= topN: continue
            n += 1
            print( '   %.3f %s' % ( score, w) )

# %%
import json
fw = open( 'kdd2018_papers.json', 'w' )
json.dump( papers, fw, indent=4 )

# %% [markdown]
# ### TFIDF

# %%
filteringPos = ['NN', 'NNP', 'JJ']
Texts = get_texts_from_papers( papers )
BoWsNoun = get_BoWs_from_english_rawtext( Texts, filteringPos )

# %%
Corpus, Dictionary, Tfidf = get_tfidf( BoWsNoun )
TfidfScores = get_tfidf_each_document( Corpus, Dictionary, Tfidf )
TfidfEachWord = get_tfidf_each_word( TfidfScores )

# %%
get_keywords( TfidfEachWord, 10 )
# Out:
#    7.976 network
#    7.682 graph
#    6.735 user
#    6.429 recommend
#    6.426 system
#    5.818 method
#    5.469 featur
#    5.391 algorithm
#    5.286 predict
#    5.060 deep

# %%
get_keywords_each_document( TfidfScores, 5 )
# Out:
# 0 Smoothed Dilated Convolutions for Improved Dense Prediction
#    0.603 convolut
#    0.359 dcnn
#    0.240 smooth
#    0.220 artifact
#    0.220 decomposit
# 1 Discovering Non-Redundant K-means Clusterings in Optimal Subspaces
#    0.472 cluster
#    0.316 k-mean
#    0.268 subspac
#    0.248 particularli
#    0.240 high-dimension
# 2 Trajectory-driven Influential Billboard Placement
#    0.401 influenti
#    0.300 budget
#    0.280 trajectori
#    0.272 influenc
#    0.272 ratio
# 3 Multi-Type Itemset Embedding for Learning Behavior Success
#    0.566 item
#    0.481 behavior
#    0.300 success
#    0.247 context
#    0.150 maker
# 4 STAMP: Short-Term Attention/Memory Priority Model for Session-based Recommendation
#    0.340 short-term
#    0.291 memori
#    0.287 session
#    0.275 user
#    0.244 prioriti
# 5 Calibrated Multi-Task Learning
#    0.399 non-convex
#    0.388 regular
#    0.326 calibr
#    0.285 loss
#    0.228 multi-task
# 6 Unlearn What You Have Learned: Adaptive Crowd Teaching with Exponentially Decayed Memory Learners
#    0.677 crowdsourc
#    0.245 crowd
#    0.245 decay
#    0.211 worker
#    0.202 adapt
# 7 Interactive Paths Embedding for Semantic Proximity Search on Heterogeneous Graphs
#    0.639 path
#    0.413 proxim
#    0.262 semant
#    0.253 object
#    0.237 heterogen
# 8 Scalable Active Learning by Approximated Error Reduction
#    0.528 reduct
#    0.369 error
#    0.273 activ
#    0.271 candid
#    0.198 approxim
# 9 R2SDH: Robust Rotated Supervised Discrete Hashing
#    0.495 rotat
#    0.483 hash
#    0.244 discret
#    0.228 r
#    0.200 supervis
# 10 Learning Adversarial Networks for Semi-Supervised Text Classification via Policy Gradient
#    0.550 semi-supervis
#    0.304 predictor
#    0.263 text
#    0.208 network
#    0.164 polici
# 11 Multi-view Adversarially Learned Inference for Cross-domain Joint Distribution Matching
#    0.334 pair
#    0.253 sampl
#    0.250 adversari
#    0.239 cross-domain
#    0.233 map
# 12 Disturbance Grassmann Kernels for Subspace-Based Learning
#    0.557 kernel
#    0.446 subspac
#    0.387 classifi
#    0.194 kind
#    0.163 linear
# 13 Finding Similar Exercises with a Unified Semantic Representation
#    0.421 similar
#    0.280 text
#    0.270 semant
#    0.235 concept
#    0.235 unifi
# 14 Supervised Reinforcement Learning with Recurrent Neural Network for Dynamic Treatment Recommendation
#    0.357 signal
#    0.329 prescript
#    0.298 reinforc
#    0.257 supervis
#    0.250 indic
# 15 Transcribing Content from Structural Images with Spotlight Mechanism
#    0.616 spotlight
#    0.338 content
#    0.308 transcrib
#    0.286 imag
#    0.202 structur
# 16 StockAssIstant: A Stock AI Assistant for Reliability Modeling of Stock Comments
#    0.815 stock
#    0.272 analyst
#    0.254 reliabl
#    0.159 opinion
#    0.136 investor
# 17 Leveraging Meta-path based Context for Top N recommendation with Co-attention mechanism
#    0.437 context
#    0.366 co-attent
#    0.279 recommend
#    0.229 hin
#    0.217 leverag
# 18 Subspace Network: Deep Multi-Task Censored Regression for Modeling Neurodegenerative Diseases
#    0.609 subspac
#    0.335 censor
#    0.312 multi-task
#    0.215 clinic
#    0.204 score
# 19 Learning Dynamics of Decision Boundaries without Additional Labeled Data
#    0.396 decis
#    0.280 classifi
#    0.260 label
#    0.248 dynam
#    0.237 criterion
# 20 Arbitrary-Order Proximity Preserved Network Embedding
#    0.635 proxim
#    0.301 preserv
#    0.290 order
#    0.209 theorem
#    0.180 high-ord
# 21 Scalable k-Means Clustering via Lightweight Coresets
#    0.484 lightweight
#    0.354 cluster
#    0.323 k
#    0.297 allow
#    0.184 error
# 22 Voxel Deconvolutional Networks for 3D Brain Image Labeling
#    0.499 layer
#    0.384 artifact
#    0.279 adni
#    0.248 %
#    0.240 brain
# 23 Count-Min: Optimal Estimation and Tight Error Bounds using Empirical Error Distributions
#    0.557 estim
#    0.407 error
#    0.368 sketch
#    0.305 count
#    0.201 bound
# 24 Metric Learning from Probabilistic Labels
#    0.574 metric
#    0.447 probabilist
#    0.383 label
#    0.237 mechan
#    0.208 distanc
# 25 TextTruth: An Unsupervised Approach to Discover Trustworthy Information from Multi-Sourced Text Data
#    0.572 trustworthi
#    0.389 answer
#    0.349 text
#    0.243 truth
#    0.221 factor
# 26 HeavyGuardian: Separate and Guard Hot Items in Data Streams
#    0.365 frequenc
#    0.312 heavi
#    0.312 hot
#    0.285 stream
#    0.252 item
# 27 Can Who-Edits-What Predict Edit Survival?
#    0.462 surviv
#    0.425 reput
#    0.265 predictor
#    0.240 special
#    0.209 project
# 28 Graph Classification using Structural Attention
#    0.791 graph
#    0.206 entir
#    0.196 classif
#    0.175 calcul
#    0.175 portion
# 29 Opinion Dynamics with Varying Susceptibility to Persuasion
#    0.701 opinion
#    0.409 suscept
#    0.245 budget
#    0.225 intervent
#    0.157 peopl
# 30 Efficient Attribute Recommendation with Probabilistic Guarantee
#    0.493 tabl
#    0.314 exact
#    0.314 speedup
#    0.258 attribut
#    0.240 guarante
# 31 You Are How You Drive: Peer and Temporal-Aware Representation Learning for Driving Behavior Analysis
#    0.773 drive
#    0.338 peer
#    0.247 behavior
#    0.166 driver
#    0.142 represent
# 32 Simultaneous Urban Region Function Discovery and Popularity Estimation Via an Infinite Urbanization
#    0.834 urban
#    0.295 region
#    0.148 pattern
#    0.144 function
#    0.114 cross-domain
# 33 MiSoSouP: Mining Interesting Subgroups with Sampling and Pseudodimension
#    0.648 subgroup
#    0.394 sampl
#    0.243 high-qual
#    0.202 interest
#    0.165 approxim
# 34 NetLSD: Hearing the Shape of a Graph
#    0.708 graph
#    0.378 comparison
#    0.231 shape
#    0.213 laplacian
#    0.173 express
# 35 Efficient Large-Scale Fleet Management via Multi-Agent Deep Reinforcement Learning
#    0.500 fleet
#    0.345 multi-ag
#    0.323 contextu
#    0.292 manag
#    0.234 reinforc
# 36 A Dual Markov Chain Topic Model for Dynamic Environments
#    0.600 topic
#    0.365 markov
#    0.215 dual
#    0.211 dynam
#    0.131 time
# 37 An Efficient Two-Layer Mechanism for Privacy-Preserving Truth Discovery
#    0.412 aggreg
#    0.402 answer
#    0.375 mechan
#    0.300 privaci
#    0.287 truth
# 38 SUSTain: Scalable Unsupervised Scoring for Tensors and its Application to Phenotyping
#    0.440 integ
#    0.336 score
#    0.330 tensor
#    0.220 real-valu
#    0.220 subproblem
# 39 Learning Deep Network Representations with Adversarially Regularized Autoencoders
#    0.472 vertex
#    0.340 represent
#    0.254 reconstruct
#    0.238 network
#    0.233 adversari
# 40 FASTEN: Fast Sylvester Equation Solver for Graph Mining
#    0.676 equat
#    0.290 \em
#    0.273 graph
#    0.151 subspac
#    0.151 exact
# 41 TINET: Learning Invariant Networks via Knowledge Transfer
#    0.276 entiti
#    0.254 network
#    0.252 construct
#    0.241 environ
#    0.238 system
# 42 Modeling Task Relationships in Multi-task Learning with Multi-gate Mixture-of-Experts
#    0.568 multi-task
#    0.374 movi
#    0.360 task
#    0.286 relationship
#    0.171 recommend
# 43 Towards Mitigating the Class-Imbalance Problem for Partial Label Learning
#    0.469 label
#    0.348 exampl
#    0.328 partial
#    0.281 train
#    0.249 over-sampl
# 44 Exploring the Urban Region-of-Interest through the Analysis of Online Map Search Queries
#    0.602 urban
#    0.204 profil
#    0.185 inde
#    0.173 grid
#    0.173 travel
# 45 Complex Object Classification: A Multi-Modal Multi-Instance Multi-Label Deep Network with Optimal Tr
#    0.470 multi-mod
#    0.321 label
#    0.319 multi-label
#    0.235 articl
#    0.223 modal
# 46 New Robust Metric Learning Model Using Maximum Correntropy Criterion
#    0.358 metric
#    0.326 correntropi
#    0.326 m
#    0.324 distanc
#    0.300 residu
# 47 TruePIE: Discovering Reliable Patterns in Pattern-Based Information Extraction
#    0.708 pattern
#    0.431 reliabl
#    0.280 extract
#    0.185 correct
#    0.151 inform
# 48 Network Connectivity Optimization: Fundamental Limits and Effective Algorithms
#    0.402 optim
#    0.370 connect
#    0.278 fundament
#    0.230 side
#    0.193 network
# 49 Risk Prediction on Electronic Healthcare Records with Prior Medical Knowledge
#    0.497 medic
#    0.450 risk
#    0.315 prior
#    0.232 knowledg
#    0.198 posterior
# 50 Ranking Distillation: Learning Compact Ranking Models With High Performance for Recommender System
#    0.573 teacher
#    0.513 rank
#    0.468 student
#    0.187 learnt
#    0.145 recommend
# 51 xDeepFM: Combining Explicit and Implicit Feature Interactions for Recommender Systems
#    0.413 interact
#    0.343 featur
#    0.263 dnn
#    0.223 combinatori
#    0.223 implicitli
# 52 NetWalk: A Flexible Deep Embedding Approach for Anomaly Detection in Dynamic Networks
#    0.397 network
#    0.378 anomali
#    0.364 dynam
#    0.248 represent
#    0.236 vertic
# 53 Cost-Effective Training of Deep CNNs with Active Model Adaptation
#    0.522 pre-train
#    0.300 activ
#    0.284 cost-effect
#    0.268 label
#    0.239 exampl
# 54 Adversarial Detection with Model Interpretation
#    0.452 adversari
#    0.346 detect
#    0.293 interpret
#    0.259 manipul
#    0.220 detector
# 55 Offline Evaluation of Ranking Policies with Click Models
#    0.518 click
#    0.415 list
#    0.362 estim
#    0.321 rank
#    0.201 polici
# 56 REST: A Reference-based Framework for Spatio-temporal Trajectory Compression
#    0.685 trajectori
#    0.514 compress
#    0.229 refer
#    0.210 spatio-tempor
#    0.140 rest
# 57 Efficient Similar Region Search with Deep Metric Learning
#    0.529 region
#    0.329 search
#    0.311 similar
#    0.202 effici
#    0.154 object
# 58 High-order Proximity Preserving Information Network Hashing
#    0.446 high-ord
#    0.351 proxim
#    0.324 code
#    0.281 binari
#    0.244 node
# 59 Decoupled Learning for Factorial Marked Temporal Point Processes
#    0.586 marker
#    0.334 point
#    0.246 tempor
#    0.241 event
#    0.193 discret
# 60 R-VQA: Learning Visual Relation Facts with Semantic Attention for Visual Question Answering
#    0.568 visual
#    0.351 semant
#    0.315 fact
#    0.274 relat
#    0.223 attent
# 61 Multi-label Learning with Highly Incomplete Data via Collaborative Embedding
#    0.530 multi-label
#    0.485 incomplet
#    0.251 assign
#    0.228 label
#    0.194 transduct
# 62 Spectral Clustering of Large-scale Data by Directly Solving Normalized Cut
#    0.422 cut
#    0.388 anchor
#    0.347 cluster
#    0.295 normal
#    0.258 spectral
# 63 SpotLight: Detecting Anomalies in Streaming Graphs
#    0.321 spotlight
#    0.302 graph
#    0.250 ‘
#    0.231 sketch
#    0.200 edg
# 64 Learning Representations of Ultrahigh-dimensional Data for Random Distance-based Outlier Detection
#    0.444 outlier
#    0.382 represent
#    0.335 detect
#    0.272 unstabl
#    0.250 curs
# 65 Dynamic Embeddings for User Profiling in Twitter
#    0.463 dynam
#    0.420 twitter
#    0.295 keyword
#    0.253 user
#    0.239 word
# 66 A Unified Approach to Quantifying Algorithmic Unfairness: Measuring Individual & Group Unfairness vi
#    0.565 fair
#    0.282 measur
#    0.262 un
#    0.252 individu
#    0.226 defin
# 67 Multiview Clustering via Adaptively Weighted Procrustes
#    0.411 weight
#    0.390 cluster
#    0.349 spectral
#    0.289 view
#    0.285 rotat
# 68 Deep Variational Network Embedding in Wasserstein Space
#    0.415 uncertainti
#    0.397 node
#    0.260 network
#    0.252 variat
#    0.238 space
# 69 Geographical Hidden Markov Tree for Flood Extent Mapping
#    0.386 flood
#    0.372 hidden
#    0.307 map
#    0.301 markov
#    0.288 class
# 70 Embedding Temporal Network via Neighborhood Formation
#    0.456 tempor
#    0.406 neighbor
#    0.274 node
#    0.272 format
#    0.236 influenc
# 71 Algorithms for Hiring and Outsourcing in the Online Labor Market
#    0.397 hire
#    0.387 team
#    0.342 worker
#    0.342 member
#    0.273 labor
# 72 Data Diff: Interpretable, Executable Summaries of Changes in Distributions for Data Wrangling
#    0.612 diff
#    0.263 repeat
#    0.175 tool
#    0.153 summari
#    0.153 inconsist
# 73 Hierarchical Taxonomy Aware Network Embedding
#    0.559 taxonomi
#    0.454 hierarch
#    0.335 categori
#    0.289 vertic
#    0.227 granular
# 74 Exact and Consistent Interpretation for Piecewise Linear Neural Networks: A Closed Form Solution
#    0.418 exact
#    0.348 interpret
#    0.306 linear
#    0.283 consist
#    0.246 pre-train
# 75 TaxoGen: Constructing Topical Concept Taxonomy by Adaptive Term Embedding and Clustering
#    0.533 taxonomi
#    0.397 topic
#    0.362 term
#    0.227 cluster
#    0.206 recurs
# 76 Deep Recursive Network Embedding with Regular Equivalence
#    0.656 equival
#    0.374 recurs
#    0.334 regular
#    0.176 node
#    0.165 network
# 77 PCA by Determinant Optimization has no Spurious Local Optima
#    0.360 theorem
#    0.302 compon
#    0.294 non-convex
#    0.281 interpret
#    0.252 program
# 78 Concepts-Bridges: Uncovering Conceptual Bridges Based on Biomedical Concept Evolution
#    0.505 concept
#    0.348 conceptu
#    0.218 semant
#    0.202 corpu
#    0.161 map
# 79 Learning and Interpreting Complex Distributions in Empirical Data
#    0.384 empir
#    0.327 dynam
#    0.323 complex
#    0.312 distribut
#    0.183 way
# 80 Concentrated Differentially Private Gradient Descent with Adaptive per-Iteration Privacy Budget
#    0.437 privat
#    0.363 gradient
#    0.343 iter
#    0.291 privaci
#    0.291 differenti
# 81 Adversarial Attacks on Neural Networks for Graph Data
#    0.550 attack
#    0.358 graph
#    0.328 perturb
#    0.244 adversari
#    0.239 node
# 82 Optimal Distributed Submodular Optimization via Sketching
#    0.433 submodular
#    0.321 optim
#    0.288 mapreduc
#    0.282 algorithm
#    0.248 coverag
# 83 Stable Prediction across Unknown Environments
#    0.447 stabl
#    0.427 balanc
#    0.316 unknown
#    0.245 environ
#    0.236 global
# 84 Feedback-Guided Anomaly Discovery via Online Optimization
#    0.672 anomali
#    0.407 feedback
#    0.299 analyst
#    0.166 interest
#    0.156 detector
# 85 Active Feature Acquisition with Supervised Matrix Completion
#    0.485 featur
#    0.283 acquisit
#    0.249 supervis
#    0.244 activ
#    0.228 valu
# 86 Node Similarity with q-Grams for Real-World Labeled Networks
#    0.325 jaccard
#    0.325 q
#    0.306 label
#    0.253 index
#    0.243 exponenti
# 87 Multi-Pointer Co-Attention Networks for Recommendation
#    0.717 review
#    0.220 co-attent
#    0.206 user-item
#    0.201 recommend
#    0.183 mechan
# 88 Scalable Spectral Clustering Using Random Binning Features
#    0.585 spectral
#    0.505 cluster
#    0.179 matrix
#    0.172 similar
#    0.165 random
# 89 Model-based Clustering of Short Text Streams
#    0.457 short
#    0.386 stream
#    0.354 text
#    0.347 cluster
#    0.291 model-bas
# 90 A Treatment Engine by Predicting Next-Period Prescriptions
#    0.432 treatment
#    0.307 lstm
#    0.293 prescript
#    0.266 record
#    0.230 medic
# 91 IntelliLight: a Reinforcement Learning Approach for Intelligent Traffic Light Control
#    0.607 traffic
#    0.474 light
#    0.409 control
#    0.212 reinforc
#    0.207 intellig
# 92 Towards Explanation of DNN-based Prediction with Guided Feature Inversion
#    0.511 interpret
#    0.444 dnn
#    0.246 dnn-base
#    0.226 explan
#    0.226 guid
# 93 Sequences of Sets
#    0.349 partial
#    0.344 set
#    0.275 sequenc
#    0.265 send
#    0.243 sometim
# 94 Multi-Round Influence Maximization
#    0.653 round
#    0.435 seed
#    0.231 adapt
#    0.171 influenc
#    0.168 multi-round
# 95 Generalized Score Functions for Causal Discovery
#    0.646 causal
#    0.360 discoveri
#    0.207 class
#    0.172 function
#    0.162 variabl
# 96 XiaoIce Band: A Melody and Arrangement Generation Framework for Pop Music
#    0.838 music
#    0.206 track
#    0.204 gener
#    0.158 progress
#    0.120 accompani
# 97 Deep r-th Root Rank Supervised Joint Binary Embedding for Multivariate Time Series Retrieval
#    0.546 seri
#    0.420 multivari
#    0.249 time
#    0.228 rank
#    0.183 segment
# 98 FAHES: A Robust Disguised Missing Values Detector
#    0.576 miss
#    0.488 valu
#    0.315 detect
#    0.179 explicitli
#    0.179 outlier
# 99 Dynamic Bike Reposition: A Spatio-Temporal Reinforcement Learning Approach
#    0.401 cluster
#    0.365 spatio-tempor
#    0.314 bike
#    0.298 station
#    0.228 reinforc
# 100 Multi-User Mobile Sequential Recommendation: An Efficient Parallel Computing Paradigm
#    0.320 parallel
#    0.303 driver
#    0.268 rout
#    0.238 mobil
#    0.234 recommend
# 101 Local Latent Space Models for Top-N Recommendation
#    0.664 aspect
#    0.397 latent
#    0.332 subset
#    0.252 user
#    0.192 care
# 102 Investor-Imitator: A Framework for Trading Knowledge Extraction
#    0.672 trade
#    0.390 investor
#    0.312 logic
#    0.234 invest
#    0.202 descriptor
# 103 Discrete Ranking-based Matrix Factorization with Self-Paced Learning
#    0.423 binari
#    0.308 recommend
#    0.289 discret
#    0.269 self-pac
#    0.228 hash
# 104 LARC: Learning Activity-Regularized overlapping Communities across Time
#    0.702 commun
#    0.293 overlap
#    0.239 period
#    0.223 tempor
#    0.170 interact
# 105 EvoGraph: An Effective and Efficient Graph Upscaling Method for Preserving Graph Properties
#    0.760 graph
#    0.272 properti
#    0.269 preserv
#    0.248 runtim
#    0.134 origin
# 106 Training Big Random Forests with Little Resources
#    0.432 tree
#    0.309 forest
#    0.250 random
#    0.241 instanc
#    0.231 hundr
# 107 Large-Scale Learnable Graph Convolutional Networks
#    0.475 graph
#    0.424 convolut
#    0.273 fix
#    0.182 filter
#    0.176 neighbor
# 108 Online Adaptive Asymmetric Active Learning for Budgeted Imbalanced Data
#    0.669 asymmetr
#    0.382 imbalanc
#    0.215 budget
#    0.191 cost-sensit
#    0.191 isol
# 109 Multi-Label Inference for Crowdsourcing
#    0.529 label
#    0.469 crowdsourc
#    0.239 multi-label
#    0.239 true
#    0.188 multi-class
# 110 Deep Adversarial Learning for Multi-Modality Missing Data Completion
#    0.514 modal
#    0.393 miss
#    0.362 multi-mod
#    0.195 imag
#    0.193 alzheim
# 111 SPARC: Self-Paced Network Representation for Few-Shot Rare Category Characterization
#    0.616 rare
#    0.548 categori
#    0.312 character
#    0.159 exampl
#    0.155 detect
# 112 Towards Evolutionary Compression
#    0.511 compress
#    0.452 filter
#    0.343 cnn
#    0.269 evolutionari
#    0.209 redund
# 113 Accurate and Fast Asymmetric Locality-Sensitive Hashing Scheme for Maximum Inner Product Search
#    0.502 search
#    0.452 asymmetr
#    0.245 transform
#    0.237 scheme
#    0.208 maximum
# 114 Parsing to Programs: A Framework for Situated QA
#    0.665 question
#    0.414 physic
#    0.354 program
#    0.218 formal
#    0.207 situat
# 115 Dual Memory Neural Computer for Asynchronous Two-view Sequential Learning
#    0.410 view
#    0.363 mode
#    0.332 memori
#    0.262 encod
#    0.222 dual
# 116 Automated Local Regression Discontinuity Design Discovery
#    0.454 discontinu
#    0.259 regress
#    0.228 local
#    0.227 unobserv
#    0.209 scientif
# 117 PME: Projected Metric Embedding on Heterogeneous Networks for Link Prediction
#    0.330 space
#    0.308 relat
#    0.302 link
#    0.283 proxim
#    0.270 hin
# 118 Content to Node: Self-translation Network Embedding
#    0.431 content
#    0.272 sequenc
#    0.246 node
#    0.206 network
#    0.204 neighborhood
# 119 Isolation Kernel and Its Effect on SVM
#    0.729 kernel
#    0.468 isol
#    0.187 svm
#    0.146 explicit
#    0.127 classifi
# 120 Variable Selection and Task Grouping for Multi-Task Learning
#    0.326 altern
#    0.326 multi-task
#    0.308 variabl
#    0.252 group
#    0.247 select
# 121 Are your data gathered?
#    0.369 multivari
#    0.307 statist
#    0.235 cluster
#    0.230 distribut
#    0.214 straightforward
# 122 Quantifying Uncertainty in Discrete-Continuous and Skewed Data with Bayesian Deep Learning
#    0.579 uncertainti
#    0.336 skew
#    0.252 gaussian
#    0.201 distribut
#    0.196 extrem
# 123 Efficient Mining of the Most Significant Patterns with Permutation Testing
#    0.558 pattern
#    0.467 signific
#    0.238 top-k
#    0.213 extract
#    0.187 output
# 124 On Interpretation of Network Embedding via Taxonomy Induction
#    0.467 interpret
#    0.418 embed
#    0.388 taxonomi
#    0.206 network
#    0.178 space
# 125 Neural Memory Streaming Recommender Networks with Adversarial Training
#    0.493 stream
#    0.437 recommend
#    0.190 memori
#    0.189 stabl
#    0.156 long-term
# 126 Extremely Fast Decision Tree
#    0.827 tree
#    0.212 decis
#    0.173 extrem
#    0.148 implement
#    0.148 asymptot
# 127 Easing Embedding Learning by Comprehensive Transcription of Heterogeneous Information Networks
#    0.743 hin
#    0.384 transcript
#    0.280 heterogen
#    0.180 edg
#    0.126 inform
# 128 On the Generative Discovery of Structured Medical Knowledge
#    0.678 medic
#    0.430 pair
#    0.387 entiti
#    0.141 relat
#    0.134 prepar
# 129 Accelerated Equivalence Structure Extraction via Pairwise Incremental Search
#    0.411 equival
#    0.395 k
#    0.340 increment
#    0.308 pairwis
#    0.293 search
# 130 Unlocking the Value of Privacy: Trading Aggregate Statistics over Private Correlated Data
#    0.587 privaci
#    0.352 privat
#    0.248 trade
#    0.208 price
#    0.206 statist
# 131 Learning from History and Present: Next-item Recommendation via Discriminatively Exploiting User Beh
#    0.412 item
#    0.336 prefer
#    0.291 behavior
#    0.259 discrimin
#    0.234 consumpt
# 132 Robust Bayesian Kernel Machine via Stein Variational Gradient Descent for Big Data
#    0.527 kernel
#    0.361 bayesian
#    0.338 bkm
#    0.291 tune
#    0.238 robust
# 133 Recurrent Binary Embedding for GPU-Enabled Exhaustive Retrieval from Billion-Scale Semantic Vectors
#    0.441 binari
#    0.426 retriev
#    0.263 semant
#    0.254 vector
#    0.244 billion-scal
# 134 DILOF: Effective and Memory Efficient Local Outlier Detection in Data Streams
#    0.571 outlier
#    0.427 stream
#    0.287 detect
#    0.229 execut
#    0.145 sequenc
# 135 Learning Structural Node Embeddings via Diffusion Wavelets
#    0.403 node
#    0.285 topolog
#    0.285 diffus
#    0.285 wavelet
#    0.282 role
# 136 Transfer Learning via Feature Isomorphism Discovery
#    0.487 transfer
#    0.348 domain
#    0.279 featur
#    0.234 correspond
#    0.230 instanc
# 137 Demand-Aware Charger Planning for Electric Vehicle Sharing
#    0.654 charg
#    0.393 electr
#    0.225 vehicl
#    0.214 station
#    0.194 share
# 138 Multi-task Representation Learning for Travel Time Estimation
#    0.459 travel
#    0.289 rout
#    0.279 multi-task
#    0.267 destin
#    0.260 time
# 139 Safe Triplet Screening for Distance Metric Learning
#    0.628 screen
#    0.605 safe
#    0.241 metric
#    0.134 huge
#    0.131 distanc
# 140 Self-Paced Network Embedding
#    0.689 node
#    0.288 self-pac
#    0.287 context
#    0.206 neg
#    0.203 sampl
# 141 Sketched Follow-The-Regularized-Leader for Online Factorization Machine
#    0.312 matric
#    0.276 sketch
#    0.265 onlin
#    0.208 machin
#    0.192 paramet
# 142 Coupled Context Modeling for Deep Chit-Chat: Towards Conversations between Human and Computer
#    0.301 human
#    0.295 context
#    0.254 system
#    0.213 big
#    0.204 relev
# 143 Learning-to-Ask: Knowledge Acquisition via 20 Questions
#    0.511 question
#    0.447 acquisit
#    0.304 agent
#    0.236 knowledg
#    0.195 seek
# 144 Multi-Cast Attention Networks
#    0.649 attent
#    0.250 co-attent
#    0.195 e.g.
#    0.162 layer
#    0.139 mechan
# 145 Context-aware Academic Collaborator Recommendation
#    0.736 collabor
#    0.361 academ
#    0.237 topic
#    0.209 research
#    0.170 conserv
# 146 RAIM: Recurrent Attentive and Intensive Modeling of Multimodal Continuous Patient Monitoring Data
#    0.426 monitor
#    0.320 medic
#    0.277 patient
#    0.258 continu
#    0.222 ecg
# 147 Route Recommendations for Idle Taxi Drivers: Find Me the Shortest Route to a Customer!
#    0.510 taxi
#    0.401 rout
#    0.389 custom
#    0.287 request
#    0.272 driver
# 148 Hyperparameter Importance Across Datasets
#    0.865 hyperparamet
#    0.208 autom
#    0.134 methodolog
#    0.126 progress
#    0.126 import
# 149 Classifying and Counting with Recurrent Contexts
#    0.373 class
#    0.333 proport
#    0.305 stream
#    0.292 classif
#    0.235 label
# 150 Multilevel Wavelet Decomposition Network for Interpretable Time Series Analysis
#    0.434 seri
#    0.317 frequenc
#    0.305 wavelet
#    0.305 multilevel
#    0.280 decomposit
# 151 Active Opinion Maximization in Social Networks
#    0.676 opinion
#    0.231 user
#    0.219 product
#    0.183 activ
#    0.182 maxim
# 152 Identifying Sources and Sinks in the Presence of Multiple Agents with Gaussian Process Vector Calcul
#    0.631 agent
#    0.232 presenc
#    0.231 field
#    0.226 environ
#    0.210 vector
# 153 Deep Censored Learning of the Winning Price in the Real Time Bidding
#    0.708 win
#    0.512 price
#    0.202 censor
#    0.185 deep
#    0.160 observ
# 154 Optimizing cluster-based randomized experiments under monotonicity
#    0.475 monoton
#    0.317 bia
#    0.317 interfer
#    0.274 design
#    0.259 auction
# 155 Learning Credible Models
#    0.356 eye
#    0.323 expert
#    0.258 reason
#    0.247 regular
#    0.231 risk
# 156 Explanation Mining: Post Hoc Interpretability of Latent Factor Models for Recommendation Systems
#    0.478 explan
#    0.359 black-box
#    0.291 latent
#    0.273 recommend
#    0.270 interpret
# 157 Quantifying and minimizing risk of conflict in social networks
#    0.498 opinion
#    0.426 quantifi
#    0.367 conflict
#    0.273 peopl
#    0.214 social
# 158 A Distributed Quasi-Newton Algorithm for Empirical Risk Minimization with Nonsmooth Regularization
#    0.335 regular
#    0.306 second-ord
#    0.292 convex
#    0.270 solv
#    0.269 distribut
# 159 DeepInf: Social Influence Prediction with Deep Learning
#    0.498 influenc
#    0.369 social
#    0.245 indispens
#    0.245 everyday
#    0.245 friend
# 160 An Iterative Global Structure-Assisted Labeled Network Aligner
#    0.614 align
#    0.520 graph
#    0.198 global
#    0.157 iter
#    0.123 concret
# 161 Discovering Models from Structural and Behavioral Brain Imaging Data
#    0.647 block
#    0.362 behavior
#    0.280 graph
#    0.228 structur
#    0.171 brain
# 162 On Discrimination Discovery and Removal in Ranked Data using Causal Graph
#    0.577 rank
#    0.466 discrimin
#    0.343 causal
#    0.197 fair
#    0.162 graph
# 163 Fairness of Exposure in Rankings
#    0.536 fair
#    0.418 rank
#    0.328 constraint
#    0.249 exposur
#    0.214 job
# 164 BagMinHash - Minwise Hashing Algorithm for Weighted Sets
#    0.525 signatur
#    0.379 weight
#    0.273 hash
#    0.190 algorithm
#    0.175 jaccard
# 165 Enhancing Predictive Modeling of Nested Spatial Data through Group-Level Feature Disaggregation
#    0.330 multilevel
#    0.330 nest
#    0.281 limit
#    0.267 group
#    0.260 featur
# 166 New Incremental Learning Algorithm for  Semi-Supervised  Support Vector Machine
#    0.492 increment
#    0.356 semi-supervis
#    0.257 path
#    0.229 loop
#    0.229 minimum
# 167 D2K: Scalable Community Detection in Massive Networks via Small-Diameter k-Plexes
#    0.413 commun
#    0.383 graph
#    0.254 edg
#    0.204 implement
#    0.203 cliqu
# 168 Butterfly Counting in Bipartite Networks
#    0.574 bipartit
#    0.468 count
#    0.208 bicliqu
#    0.196 graph
#    0.179 provabl
# 169 An Empirical Evaluation of Sketching for Numerical Linear Algebra
#    0.349 regress
#    0.306 algebra
#    0.263 squar
#    0.257 rank
#    0.234 approxim
# 170 Deep Multi-Output Forecasting: Learning to Accurately Predict Blood Glucose Trajectories
#    0.521 forecast
#    0.412 blood
#    0.284 multi-step
#    0.258 futur
#    0.232 signal
# 171 Active Search of Connections for Case Building and Combating Human Trafficking
#    0.409 connect
#    0.321 evid
#    0.321 investig
#    0.302 case
#    0.262 activ
# 172 Not Just Privacy: Improving Performance of Private Deep Learning in Mobile Cloud
#    0.499 cloud
#    0.443 privaci
#    0.348 mobil
#    0.250 center
#    0.232 devic
# 173 xStream: Outlier Detection in Feature-Evolving Data Streams
#    0.531 stream
#    0.314 static
#    0.237 outlier
#    0.226 detector
#    0.203 updat
# 174 Semi-Supervised Generative Adversarial Network for Gene Expression Inference
#    0.794 gene
#    0.372 express
#    0.298 landmark
#    0.134 profil
#    0.128 gan
# 175 HiExpan: Task-Guided Taxonomy Construction by Hierarchical Tree Expansion
#    0.882 taxonomi
#    0.199 construct
#    0.147 seed
#    0.128 corpu
#    0.119 tree
# 176 Prediction-time Efficient Classification Using Feature Computational Dependencies
#    0.403 comput
#    0.338 featur
#    0.268 redund
#    0.235 cost
#    0.194 substanti
# 177 Approximating the Spectrum of a Graph
#    0.598 spectrum
#    0.511 graph
#    0.199 =
#    0.169 calcul
#    0.134 larg
# 178 When Sentiment Analysis Meets Social Network: A Holistic User Behavior Modeling in Opinionated Data
#    0.416 intent
#    0.398 opinion
#    0.377 user
#    0.255 neglect
#    0.255 user-gener
# 179 Latent variable time-varying network inference
#    0.355 graphic
#    0.312 variabl
#    0.265 latent
#    0.237 biolog
#    0.218 time-seri
# 180 Stablizing Reinforcement Learning in Dynamic Environment with Application to Online Recommendation
#    0.504 environ
#    0.385 reward
#    0.321 reinforc
#    0.290 dynam
#    0.272 robust
# 181 I Know You’ll Be Back: Interpretable New User Clustering and Churn Prediction on a Mobile Social App
#    0.514 dispatch
#    0.257 immedi
#    0.239 order
#    0.210 driver
#    0.180 plan
# 182 PrePeP – A Tool for the Identification and Characterization of Pan Assay Interference Compounds
#    0.518 compound
#    0.322 tool
#    0.229 visual
#    0.188 interfer
#    0.173 imbal
# 183 Large-Scale Order Dispatch in On-Demand Ride-Sharing Platforms: A Learning and Planning Approach
#    0.569 dispatch
#    0.264 order
#    0.238 plan
#    0.228 immedi
#    0.228 on-demand
# 184 WattHome: Identifying Energy-Inefficient Homes at City-scale
#    0.582 build
#    0.310 home
#    0.253 fault
#    0.225 %
#    0.206 ineffici
# 185 Perceive Your Users in Depth: Learning Universal User Representations from Multiple E-commerce Tasks
#    0.344 task
#    0.332 person
#    0.332 e-commerc
#    0.259 overload
#    0.238 depth
# 186 E-tail product return prediction via hypergraph-based local graph cut
#    0.574 return
#    0.201 product
#    0.185 rate
#    0.185 associ
#    0.185 custom
# 187 Customized Regression Model for Airbnb Dynamic Pricing
#    0.589 price
#    0.535 airbnb
#    0.252 list
#    0.233 ident
#    0.190 home
# 188 TATC: Predicting Alzheimer’s Disease with Actigraphy Data
#    0.509 ad
#    0.291 doctor
#    0.267 alzheim
#    0.238 subject
#    0.227 daili
# 189 Automatic Discovery of Tactics in Spatio-Temporal Soccer Match Data
#    0.499 match
#    0.345 team
#    0.180 automat
#    0.159 collect
#    0.147 review
# 190 Corpus Conversion Service: A machine learning platform to ingest documents at scale.
#    0.516 document
#    0.269 format
#    0.231 platform
#    0.230 machine-learn
#    0.211 ground-truth
# 191 Using Machine Learning to Assess the Risk of and Prevent Water Main Breaks
#    0.547 break
#    0.394 main
#    0.383 water
#    0.293 citi
#    0.235 p
# 192 Using Rule-Based Labels for Weak Supervised Learning: A ChemNet for Transferable Chemical Property P
#    0.347 properti
#    0.316 generaliz
#    0.312 transfer
#    0.290 pre-train
#    0.290 rule-bas
# 193 OpenTag: Open Attribute Value Extraction from Product Profiles
#    0.591 attribut
#    0.531 valu
#    0.230 miss
#    0.224 extract
#    0.154 beforehand
# 194 Detecting Spacecraft Anomalies Using LSTMs and Nonparametric Dynamic Thresholding
#    0.630 anomali
#    0.280 telemetri
#    0.241 nonparametr
#    0.202 lstm
#    0.180 dure
# 195 Online Parameter Selection for Web-based Ranking Problems
#    0.249 object
#    0.240 web-bas
#    0.240 feed
#    0.231 desir
#    0.221 linkedin
# 196 Rare Query Expansion Through Generative Adversarial Networks in Search Advertising
#    0.382 queri
#    0.344 keyword
#    0.325 advertis
#    0.296 search
#    0.265 gener
# 197 Learning and Transferring IDs Representation in E-commerce
#    0.452 item
#    0.332 transfer
#    0.243 encod
#    0.236 represent
#    0.215 e-commerc
# 198 Collaborative Deep Metric Learning for Video Understanding
#    0.786 video
#    0.212 domain
#    0.192 understand
#    0.165 metric
#    0.156 includ
# 199 Name Disambiguation in AMiner: Clustering, Maintenance, and Human in the Loop
#    0.358 loop
#    0.358 mainten
#    0.328 disambigu
#    0.328 ]
#    0.308 free
# 200 False Discovery Rate Controlled Heterogeneous Treatment Effect Detection for Online Controlled Exper
#    0.452 treatment
#    0.378 heterogen
#    0.321 control
#    0.285 a/b
#    0.223 age
# 201 Rosetta: Large scale system for text detection and recognition in images
#    0.403 recognit
#    0.320 imag
#    0.297 facebook
#    0.247 scale
#    0.204 system
# 202 Estimating Glaucomatous Visual Sensitivity from Retinal Thickness by Using Pattern-Based Regularizat
#    0.444 pattern-bas
#    0.424 cnn
#    0.393 visual
#    0.233 sensit
#    0.203 estim
# 203 Explaining Aviation Safety Incidents Using Deep Temporal Multiple Instance Learning
#    0.567 safeti
#    0.470 incid
#    0.188 explain
#    0.172 abil
#    0.172 seri
# 204 Towards station-level demand prediction for effective rebalancing in bike-sharing systems
#    0.537 demand
#    0.290 interv
#    0.250 bike
#    0.237 station
#    0.175 predict
# 205 Du-Parking: Spatio-Temporal Big Data Tells You Realtime Parking Availability
#    0.768 park
#    0.348 realtim
#    0.237 avail
#    0.174 citi
#    0.139 lot
# 206 Near real-time optimization of activity-based notifications
#    0.560 member
#    0.560 notif
#    0.198 real-tim
#    0.178 event
#    0.163 send
# 207 Accelerating Prototype-Based Drug Discovery using Conditional Diversity Networks
#    0.831 drug
#    0.312 prototyp
#    0.193 gener
#    0.132 discoveri
#    0.113 interdisciplinari
# 208 Releasing eHealth Analytics into the Wild: Lessons Learnt from the SPHERE Project
#    0.372 context
#    0.292 laboratori
#    0.292 realist
#    0.277 learnt
#    0.277 home
# 209 Real-time Personalization using Embeddings for Search Ranking at Airbnb
#    0.459 marketplac
#    0.308 list
#    0.294 airbnb
#    0.239 rank
#    0.237 search
# 210 Detecting Illegal Vehicle Parking Events using Sharing Bikes’ Trajectories
#    0.635 park
#    0.414 trajectori
#    0.255 vehicl
#    0.217 event
#    0.170 bike
# 211 Graph Convolutional Neural Networks for Web-Scale Recommender Systems
#    0.461 graph
#    0.360 recommend
#    0.342 convolut
#    0.337 web-scal
#    0.225 walk
# 212 Audience Size Forecasting: Fast and Smart Budget Planning for Media Buyers
#    0.503 campaign
#    0.409 impress
#    0.334 audienc
#    0.313 budget
#    0.204 advertis
# 213 Q&R: A Two-Stage Approach Toward Interactive Recommendation
#    0.392 q
#    0.384 recommend
#    0.360 r
#    0.270 user
#    0.240 right
# 214 ActiveRemediation: The Search for Lead Pipes in Flint, Michigan
#    0.468 pipe
#    0.363 lead
#    0.312 water
#    0.312 govern
#    0.255 feder
# 215 Winner’s Curse: Bias Estimation for Total Effects of Features in Online Controlled Experiments
#    0.466 bia
#    0.285 launch
#    0.224 control
#    0.223 statist
#    0.204 impact
# 216 Detection of Apathy in Alzheimer Patients by Analysing Visual Scanning Behaviour with RNNs
#    0.502 emot
#    0.431 patient
#    0.378 scan
#    0.255 rnn
#    0.201 individu
# 217 A Dynamic Pipeline for Spatio-Temporal Fire Risk Prediction
#    0.696 fire
#    0.459 risk
#    0.208 properti
#    0.189 incid
#    0.189 pittsburgh
# 218 Optimization of a SSP’s Header Bidding Strategy using Thompson Sampling
#    0.573 auction
#    0.409 ad
#    0.287 publish
#    0.274 bid
#    0.168 strategi
# 219 Applying the Delta method in metric analytics: A practical guide with novel ideas
#    0.479 metric
#    0.357 analyt
#    0.268 guid
#    0.182 classic
#    0.174 big
# 220 Where Will Dockless Shared Bikes be Stacked?—- Parking Hotspots Detection in a New City
#    0.538 bike
#    0.390 citi
#    0.344 park
#    0.308 share
#    0.195 densiti
# 221 Visual Search at Alibaba
#    0.491 alibaba
#    0.348 visual
#    0.267 index
#    0.265 imag
#    0.253 search
# 222 Deep Distributed Fusion Network for Air Quality Prediction
#    0.788 air
#    0.190 qualiti
#    0.174 spatial
#    0.158 meteorolog
#    0.158 hour
# 223 Deep Interest Network for Click-Through Rate Prediction
#    0.352 vector
#    0.271 click-through
#    0.237 ad
#    0.234 alibaba
#    0.225 interest
# 224 Learning Tree-based Deep Model for Recommender Systems
#    0.367 corpu
#    0.286 calcul
#    0.225 tree-bas
#    0.211 user-item
#    0.200 learnt
# 225 An Extensible Event Extraction System With Cross-Media Event Resolution
#    0.612 event
#    0.338 extract
#    0.231 system
#    0.174 capabl
#    0.162 sourc
# 226 Dynamic Pricing under Competition on Online Marketplaces: A Data-Driven Approach
#    0.517 price
#    0.404 market
#    0.343 strategi
#    0.243 competit
#    0.219 profit
# 227 PittGrub: A Frustration-Free System to Reduce Food Waste by Notifying Hungry College Students
#    0.688 wast
#    0.369 notif
#    0.197 elimin
#    0.134 transport
#    0.120 need
# 228 Autotune: A Derivative-free Optimization Framework for Hyperparameter Tuning
#    0.603 tune
#    0.500 hyperparamet
#    0.172 parallel
#    0.150 train
#    0.136 numer
# 229 Improving Box Office Result Predictions for Movies Using Consumer-Centric Models
#    0.404 movi
#    0.404 box
#    0.293 offic
#    0.199 revenu
#    0.188 individu
# 230 State space models for forecasting water quality variables: An application in aquaculture prawn farm
#    0.668 water
#    0.363 qualiti
#    0.295 forecast
#    0.197 filter
#    0.175 mean
# 231 Lessons Learned from Developing and Deploying a Large-Scale Employer Name Normalization System for O
#    0.514 employ
#    0.443 name
#    0.288 normal
#    0.274 resum
#    0.236 job
# 232 Web-Scale Responsive Visual Search at Bing
#    0.429 web-scal
#    0.428 visual
#    0.234 cascad
#    0.234 latenc
#    0.220 deploy
# 233 Distributed Collaborative Hashing and Its Applications in Ant Financial
#    0.306 hash
#    0.293 latent
#    0.283 collabor
#    0.275 recommend
#    0.274 procedur
# 234 Reinforcement Learning to Rank in E-Commerce Search Engine: Formalization, Analysis, and Application
#    0.398 rank
#    0.355 reward
#    0.342 session
#    0.263 search
#    0.248 polici
# 235 Next-Step Suggestions for Modern Interactive Data Analysis Platforms
#    0.427 modern
#    0.322 suggest
#    0.297 platform
#    0.285 session
#    0.259 analysi
# 236 COTA: Improving the Speed and Accuracy of Customer Support through Ranking and Deep Networks
#    0.362 custom
#    0.316 support
#    0.261 architectur
#    0.217 reduc
#    0.204 speed
# 237 Device Graphing by Example
#    0.514 devic
#    0.458 identifi
#    0.289 internet
#    0.158 user
#    0.156 associ
# 238 Multimodal Sentiment Analysis To Explore the Structure of Emotions
#    0.583 emot
#    0.429 sentiment
#    0.233 psycholog
#    0.216 imag
#    0.204 analysi
# 239 SDREGION: fast spotting of changing communities in biological networks
#    0.396 progress
#    0.361 biolog
#    0.295 stage
#    0.241 gene
#    0.221 earli
# 240 RapidScorer: Fast Tree Ensemble Evaluation by Maximizing Compactness in Data Level Parallelization
#    0.559 tree
#    0.506 ensembl
#    0.244 score
#    0.210 compact
#    0.187 rang
# 241 A real-time framework for detecting efficiency regressions in a globally distributed codebase
#    0.388 regress
#    0.278 detect
#    0.234 facebook
#    0.212 day
#    0.170 code
# 242 Gotcha - Sly Malware! Scorpion: A Metagraph2vec Based Malware Detection System
#    0.720 malwar
#    0.465 hin
#    0.184 detect
#    0.140 i.e.
#    0.135 secur
# 243 Career Transitions and Trajectories: A Case Study in Computing
#    0.733 career
#    0.256 trajectori
#    0.206 comput
#    0.158 artifici
#    0.150 drive
# 244 Fatigue Prediction in Outdoor Runners Via Machine Learning and Sensor Fusion
#    0.618 run
#    0.278 excess
#    0.261 sensor
#    0.247 subject
#    0.165 machin
# 245 Inferring Metapopulation Propagation Network for Intra-city Epidemic Control and Prevention
#    0.610 propag
#    0.249 transmiss
#    0.249 prevent
#    0.196 network
#    0.180 control
# 246 BigIN4: Instant, Interactive Insight Identification for Multi-Dimensional Big Data
#    0.432 queri
#    0.376 answer
#    0.359 insight
#    0.299 big
#    0.277 multi-dimension
# 247 Managing Computer-Assisted Detection System Based on Transfer Learning with Negative Transfer Inhibi
#    0.578 transfer
#    0.461 institut
#    0.248 neg
#    0.231 examin
#    0.196 manag
# 248 Billion-scale Commodity Embedding for E-commerce Recommendation in Alibaba
#    0.487 taobao
#    0.321 item
#    0.292 side
#    0.239 cold
#    0.239 billion-scal
# 249 Multi-Task Learning with Neural Networks for Voice Query Understanding on an Entertainment Platform
#    0.402 queri
#    0.294 multi-task
#    0.241 entertain
#    0.229 intent
#    0.201 neural
# 250 A Data-Driven Three-Layer Algorithm for Split Delivery Vehicle Routing Problem with 3D Container Loa
#    0.470 split
#    0.440 vehicl
#    0.369 rout
#    0.294 logist
#    0.219 data-driven
# 251 Predicting Estimated Time of Arrival for Commercial Flights
#    0.495 flight
#    0.462 eta
#    0.354 air
#    0.188 commerci
#    0.167 arriv
# 252 SQR: Balancing Speed, Quality and Risk in Online Experiments
#    0.364 innov
#    0.306 risk
#    0.240 speed
#    0.179 experi
#    0.174 decis
# 253 Optimal Allocation of Real-Time-Bidding And Direct Campaigns
#    0.444 auction
#    0.332 real-tim
#    0.317 ad
#    0.312 campaign
#    0.296 publish
# 254 Tax fraud detection for under-reporting declarations using an unsupervised machine learning approach
#    0.574 fraud
#    0.416 act
#    0.340 intent
#    0.301 return
#    0.254 form
# 255 Dynamic Recommendations for Sequential Hiring Decisions in Online Labor Markets
#    0.589 hire
#    0.319 market
#    0.294 employ
#    0.236 previous
#    0.225 decis
# 256 Assessing Candidate Preference through Web Browsing History
#    0.560 candid
#    0.385 web
#    0.327 assess
#    0.264 prefer
#    0.172 suitabl
# 257 Recommendations with Negative Feedback via Pairwise Deep Reinforcement Learning
#    0.591 feedback
#    0.478 recommend
#    0.272 neg
#    0.204 posit
#    0.194 reinforc
# 258 Product characterisation towards personalisation: Learning attributes from unstructured data to reco
#    0.557 product
#    0.283 e-commerc
#    0.221 properli
#    0.203 foundat
#    0.190 piec
# 259 A Scalable Solution for Rule-Based Part-of-Speech Tagging on Novel Hardware Accelerators
#    0.501 rule-bas
#    0.425 tag
#    0.381 rule
#    0.273 ap
#    0.213 speedup
# 260 Buy It Again: Modeling Repeat Purchase Recommendations
#    0.642 purchas
#    0.430 repeat
#    0.389 websit
#    0.192 e-commerc
#    0.168 product
# 261 Adaptive Paywall Mechanism for Digital News Media
#    0.528 reader
#    0.341 articl
#    0.337 mechan
#    0.206 news
#    0.171 potenti
# 262 Deep Sequence Learning with Auxiliary Information for Traffic Prediction
#    0.408 traffic
#    0.307 road
#    0.274 crowd
#    0.274 auxiliari
#    0.274 destin
# 263 Scalable Query N-Gram Embedding for Improving Matching and Relevance in Sponsored Search
#    0.551 queri
#    0.420 ad
#    0.331 sponsor
#    0.288 search
#    0.244 match
# 264 Scalable Optimization for Embedding Highly-Dynamic and Recency-Sensitive Data
#    0.400 sampl
#    0.396 weight
#    0.274 diffus
#    0.254 embed
#    0.192 updat
# 265 Pangloss: Fast Entity Linking in Noisy Text Environments
#    0.384 text
#    0.378 disambigu
#    0.352 entiti
#    0.206 document
#    0.198 noisi
# 266 Learning to Estimate the Travel Time
#    0.579 travel
#    0.269 eta
#    0.232 vehicl
#    0.225 time
#    0.212 solut
# 267 Anatomy of a Privacy-Safe Large-Scale Information Extraction System Over Email
#    0.719 email
#    0.290 extract
#    0.141 user
#    0.126 develop
#    0.125 inform
# 268 Exploring Student Check-In Behavior for Improved Point-of-Interest Prediction
#    0.524 check-in
#    0.339 poi
#    0.214 student
#    0.150 assumpt
#    0.141 collect
# 269 EANN: Event Adversarial Neural Networks for Multi-Modal Fake News Detection
#    0.618 fake
#    0.535 news
#    0.339 event
#    0.177 multi-mod
#    0.151 featur
# 270 Interpretable Representation Learning for Healthcare via Capturing Disease Progression through Time
#    0.645 visit
#    0.285 medic
#    0.198 decay
#    0.185 patient
#    0.170 diagnosi
# 271 Notification Volume Control and Optimization System at Pinterest
#    0.652 notif
#    0.299 volum
#    0.261 engag
#    0.249 metric
#    0.224 user
# 272 Deep Learning for Practical Image Recognition: Case Study on Kaggle Competitions
#    0.591 recognit
#    0.293 imag
#    0.197 team
#    0.193 deep
#    0.171 competit
# 273 Identify Susceptible Locations in Medical Records via Adversarial Attacks on Deep Predictive Models
#    0.464 medic
#    0.310 attack
#    0.268 record
#    0.262 ehr
#    0.214 suscept
# 274 Shield: Fast, Practical Defense and Vaccination for Deep Learning using JPEG Compression
#    0.684 compress
#    0.302 attack
#    0.209 pixel
#    0.201 adversari
#    0.194 imag
# 275 Deploying Machine Learning Models for Public Policy: A Framework
#    0.449 deploy
#    0.318 polic
#    0.318 offic
#    0.248 technic
#    0.230 machin
# 276 Detection of Paroxysmal Atrial Fibrillation using Attention based Bidirectional Recurrent Neural Net
#    0.362 detect
#    0.295 bidirect
#    0.295 ecg
#    0.276 record
#    0.271 window
# 277 Active Deep Learning To Tune Down the Noise in Labels
#    0.322 nois
#    0.317 enterpris
#    0.317 n
#    0.256 supervis
#    0.229 dnn
# 278 Resolving Abstract Anaphora in Conversational Assistants using a Hierarchically-stacked RNN
#    0.455 fact
#    0.269 utter
#    0.252 answer
#    0.231 posterior
#    0.193 queri
# 279 Mobile access record resolution on large-scale identifier-linkage graphs
#    0.503 mobil
#    0.491 record
#    0.382 access
#    0.280 devic
#    0.214 resolut
# 280 Towards Knowledge Discovery from the Vatican Secret Archives. In Codice Ratio
#    0.666 transcript
#    0.333 manuscript
#    0.222 archiv
#    0.204 charact
#    0.183 effort
# 281 Deep Reinforcement Learning for Sponsored Search Real-time Bidding
#    0.547 bid
#    0.429 auction
#    0.242 sponsor
#    0.214 advertis
#    0.175 rtb
# 282 How LinkedIn Economic Graph Bonds Information and Product: Applications in LinkedIn Salary
#    0.515 compani
#    0.479 linkedin
#    0.415 insight
#    0.174 salari
#    0.150 econom
# 283 Hetero-ConvLSTM: A Deep Learning Approach to Traffic Accident Prediction on Heterogeneous Spatio-Tem
#    0.434 accid
#    0.388 traffic
#    0.368 spatial
#    0.262 predict
#    0.217 properli
# 284 Automated Audience Segmentation Using Reputation Signals
#    0.413 signal
#    0.380 campaign
#    0.336 advertis
#    0.331 audienc
#    0.304 reput
# 285 Infrastructure Quality Assessment in Africa using Satellite Imagery and Deep Learning
#    0.570 infrastructur
#    0.312 qualiti
#    0.258 satellit
#    0.227 goal
#    0.167 region
# 286 NGUARD: A Game Bot Detection Framework for NetEase MMORPGs
#    0.912 game
#    0.135 detect
#    0.094 pattern
#    0.082 unsupervis
#    0.071 supervis
# 287 Rotation-Blended CNNs on a New Open Dataset for Tropical Cyclone Image-to-intensity Regression
#    0.364 cnn
#    0.267 open
#    0.245 task
#    0.206 accur
#    0.195 benchmark
# 288 Accelerating Large-Scale Data Analysis by Offloading to High-Performance Computing Libraries using A
#    0.537 high-perform
#    0.462 librari
#    0.303 comput
#    0.268 algebra
#    0.235 analysi
# 289 MIX: Multi-Channel Information Crossing for Text Matching
#    0.594 mix
#    0.388 text
#    0.335 match
#    0.182 sentenc
#    0.162 matric
# 290 Discovering latent patterns of urban cultural interactions in WeChat for modern city planning
#    0.728 cultur
#    0.381 urban
#    0.203 plan
#    0.182 citi
#    0.134 venu
# 291 Learning Tasks for Multitask Learning: Heterogenous Patient Populations in the ICU
#    0.597 popul
#    0.344 patient
#    0.297 group
#    0.201 heterogen
#    0.192 multi-task
# 292 StepDeep: A Novel Spatial-temporal Mobility Event Prediction Framework based on Deep Neural Network
#    0.407 mobil
#    0.392 event
#    0.365 spatial-tempor
#    0.240 predict
#    0.215 spatial

# %%
### Tfidf keyword edge

# %%
th = 0.3
keywordsEachDocument = {}
for i, scores in TfidfScores.items():
    keywordsEachDocument[i] = []
    for w, score in scores.items():
        if score > th: keywordsEachDocument[i].append( w )

# %%
tf = {}
for i, keywords in keywordsEachDocument.items():
    for k in keywords:
        if not k in tf: tf[k] = 0
        tf[k] += 1

# %%
papersWithSameKeyword = {}
for w, freq in sorted( tf.items(), key= lambda x:x[1], reverse=True ):
    if freq < 3: continue
    if len(w) < 2: continue
    print( 'Keyword: %s (Number of papers: %d)' % ( w, freq) )
    papersWithSameKeyword[w] = []
    for i, keywords in keywordsEachDocument.items():
        if w in keywords:
            print(  '   Title:', papers[i]['title'] )
            papersWithSameKeyword[w].append( i )
# Out:
# Keyword: graph (Number of papers: 10)
#    Title: Graph Classification using Structural Attention
#    Title: NetLSD: Hearing the Shape of a Graph
#    Title: SpotLight: Detecting Anomalies in Streaming Graphs
#    Title: Adversarial Attacks on Neural Networks for Graph Data
#    Title: EvoGraph: An Effective and Efficient Graph Upscaling Method for Preserving Graph Properties
#    Title: Large-Scale Learnable Graph Convolutional Networks
#    Title: An Iterative Global Structure-Assisted Labeled Network Aligner
#    Title: D2K: Scalable Community Detection in Massive Networks via Small-Diameter k-Plexes
#    Title: Approximating the Spectrum of a Graph
#    Title: Graph Convolutional Neural Networks for Web-Scale Recommender Systems
# Keyword: cluster (Number of papers: 7)
#    Title: Discovering Non-Redundant K-means Clusterings in Optimal Subspaces
#    Title: Scalable k-Means Clustering via Lightweight Coresets
#    Title: Spectral Clustering of Large-scale Data by Directly Solving Normalized Cut
#    Title: Multiview Clustering via Adaptively Weighted Procrustes
#    Title: Scalable Spectral Clustering Using Random Binning Features
#    Title: Model-based Clustering of Short Text Streams
#    Title: Dynamic Bike Reposition: A Spatio-Temporal Reinforcement Learning Approach
# Keyword: label (Number of papers: 5)
#    Title: Metric Learning from Probabilistic Labels
#    Title: Towards Mitigating the Class-Imbalance Problem for Partial Label Learning
#    Title: Complex Object Classification: A Multi-Modal Multi-Instance Multi-Label Deep Network with Optimal Tr
#    Title: Node Similarity with q-Grams for Real-World Labeled Networks
#    Title: Multi-Label Inference for Crowdsourcing
# Keyword: rank (Number of papers: 5)
#    Title: Ranking Distillation: Learning Compact Ranking Models With High Performance for Recommender System
#    Title: Offline Evaluation of Ranking Policies with Click Models
#    Title: On Discrimination Discovery and Removal in Ranked Data using Causal Graph
#    Title: Fairness of Exposure in Rankings
#    Title: Reinforcement Learning to Rank in E-Commerce Search Engine: Formalization, Analysis, and Application
# Keyword: stream (Number of papers: 5)
#    Title: Model-based Clustering of Short Text Streams
#    Title: Neural Memory Streaming Recommender Networks with Adversarial Training
#    Title: DILOF: Effective and Memory Efficient Local Outlier Detection in Data Streams
#    Title: Classifying and Counting with Recurrent Contexts
#    Title: xStream: Outlier Detection in Feature-Evolving Data Streams
# Keyword: recommend (Number of papers: 5)
#    Title: Discrete Ranking-based Matrix Factorization with Self-Paced Learning
#    Title: Neural Memory Streaming Recommender Networks with Adversarial Training
#    Title: Graph Convolutional Neural Networks for Web-Scale Recommender Systems
#    Title: Q&R: A Two-Stage Approach Toward Interactive Recommendation
#    Title: Recommendations with Negative Feedback via Pairwise Deep Reinforcement Learning
# Keyword: item (Number of papers: 4)
#    Title: Multi-Type Itemset Embedding for Learning Behavior Success
#    Title: Learning from History and Present: Next-item Recommendation via Discriminatively Exploiting User Beh
#    Title: Learning and Transferring IDs Representation in E-commerce
#    Title: Billion-scale Commodity Embedding for E-commerce Recommendation in Alibaba
# Keyword: text (Number of papers: 4)
#    Title: TextTruth: An Unsupervised Approach to Discover Trustworthy Information from Multi-Sourced Text Data
#    Title: Model-based Clustering of Short Text Streams
#    Title: Pangloss: Fast Entity Linking in Noisy Text Environments
#    Title: MIX: Multi-Channel Information Crossing for Text Matching
# Keyword: opinion (Number of papers: 4)
#    Title: Opinion Dynamics with Varying Susceptibility to Persuasion
#    Title: Active Opinion Maximization in Social Networks
#    Title: Quantifying and minimizing risk of conflict in social networks
#    Title: When Sentiment Analysis Meets Social Network: A Holistic User Behavior Modeling in Opinionated Data
# Keyword: medic (Number of papers: 4)
#    Title: Risk Prediction on Electronic Healthcare Records with Prior Medical Knowledge
#    Title: On the Generative Discovery of Structured Medical Knowledge
#    Title: RAIM: Recurrent Attentive and Intensive Modeling of Multimodal Continuous Patient Monitoring Data
#    Title: Identify Susceptible Locations in Medical Records via Adversarial Attacks on Deep Predictive Models
# Keyword: detect (Number of papers: 4)
#    Title: Adversarial Detection with Model Interpretation
#    Title: Learning Representations of Ultrahigh-dimensional Data for Random Distance-based Outlier Detection
#    Title: FAHES: A Robust Disguised Missing Values Detector
#    Title: Detection of Paroxysmal Atrial Fibrillation using Attention based Bidirectional Recurrent Neural Net
# Keyword: visual (Number of papers: 4)
#    Title: R-VQA: Learning Visual Relation Facts with Semantic Attention for Visual Question Answering
#    Title: Estimating Glaucomatous Visual Sensitivity from Retinal Thickness by Using Pattern-Based Regularizat
#    Title: Visual Search at Alibaba
#    Title: Web-Scale Responsive Visual Search at Bing
# Keyword: taxonomi (Number of papers: 4)
#    Title: Hierarchical Taxonomy Aware Network Embedding
#    Title: TaxoGen: Constructing Topical Concept Taxonomy by Adaptive Term Embedding and Clustering
#    Title: On Interpretation of Network Embedding via Taxonomy Induction
#    Title: HiExpan: Task-Guided Taxonomy Construction by Hierarchical Tree Expansion
# Keyword: transfer (Number of papers: 4)
#    Title: Transfer Learning via Feature Isomorphism Discovery
#    Title: Using Rule-Based Labels for Weak Supervised Learning: A ChemNet for Transferable Chemical Property P
#    Title: Learning and Transferring IDs Representation in E-commerce
#    Title: Managing Computer-Assisted Detection System Based on Transfer Learning with Negative Transfer Inhibi
# Keyword: ad (Number of papers: 4)
#    Title: TATC: Predicting Alzheimer’s Disease with Actigraphy Data
#    Title: Optimization of a SSP’s Header Bidding Strategy using Thompson Sampling
#    Title: Optimal Allocation of Real-Time-Bidding And Direct Campaigns
#    Title: Scalable Query N-Gram Embedding for Improving Matching and Relevance in Sponsored Search
# Keyword: queri (Number of papers: 4)
#    Title: Rare Query Expansion Through Generative Adversarial Networks in Search Advertising
#    Title: BigIN4: Instant, Interactive Insight Identification for Multi-Dimensional Big Data
#    Title: Multi-Task Learning with Neural Networks for Voice Query Understanding on an Entertainment Platform
#    Title: Scalable Query N-Gram Embedding for Improving Matching and Relevance in Sponsored Search
# Keyword: convolut (Number of papers: 3)
#    Title: Smoothed Dilated Convolutions for Improved Dense Prediction
#    Title: Large-Scale Learnable Graph Convolutional Networks
#    Title: Graph Convolutional Neural Networks for Web-Scale Recommender Systems
# Keyword: regular (Number of papers: 3)
#    Title: Calibrated Multi-Task Learning
#    Title: Deep Recursive Network Embedding with Regular Equivalence
#    Title: A Distributed Quasi-Newton Algorithm for Empirical Risk Minimization with Nonsmooth Regularization
# Keyword: proxim (Number of papers: 3)
#    Title: Interactive Paths Embedding for Semantic Proximity Search on Heterogeneous Graphs
#    Title: Arbitrary-Order Proximity Preserved Network Embedding
#    Title: High-order Proximity Preserving Information Network Hashing
# Keyword: kernel (Number of papers: 3)
#    Title: Disturbance Grassmann Kernels for Subspace-Based Learning
#    Title: Isolation Kernel and Its Effect on SVM
#    Title: Robust Bayesian Kernel Machine via Stein Variational Gradient Descent for Big Data
# Keyword: multi-task (Number of papers: 3)
#    Title: Subspace Network: Deep Multi-Task Censored Regression for Modeling Neurodegenerative Diseases
#    Title: Modeling Task Relationships in Multi-task Learning with Multi-gate Mixture-of-Experts
#    Title: Variable Selection and Task Grouping for Multi-Task Learning
# Keyword: metric (Number of papers: 3)
#    Title: Metric Learning from Probabilistic Labels
#    Title: New Robust Metric Learning Model Using Maximum Correntropy Criterion
#    Title: Applying the Delta method in metric analytics: A practical guide with novel ideas
# Keyword: answer (Number of papers: 3)
#    Title: TextTruth: An Unsupervised Approach to Discover Trustworthy Information from Multi-Sourced Text Data
#    Title: An Efficient Two-Layer Mechanism for Privacy-Preserving Truth Discovery
#    Title: BigIN4: Instant, Interactive Insight Identification for Multi-Dimensional Big Data
# Keyword: urban (Number of papers: 3)
#    Title: Simultaneous Urban Region Function Discovery and Popularity Estimation Via an Infinite Urbanization
#    Title: Exploring the Urban Region-of-Interest through the Analysis of Online Map Search Queries
#    Title: Discovering latent patterns of urban cultural interactions in WeChat for modern city planning
# Keyword: privaci (Number of papers: 3)
#    Title: An Efficient Two-Layer Mechanism for Privacy-Preserving Truth Discovery
#    Title: Unlocking the Value of Privacy: Trading Aggregate Statistics over Private Correlated Data
#    Title: Not Just Privacy: Improving Performance of Private Deep Learning in Mobile Cloud
# Keyword: risk (Number of papers: 3)
#    Title: Risk Prediction on Electronic Healthcare Records with Prior Medical Knowledge
#    Title: A Dynamic Pipeline for Spatio-Temporal Fire Risk Prediction
#    Title: SQR: Balancing Speed, Quality and Risk in Online Experiments
# Keyword: featur (Number of papers: 3)
#    Title: xDeepFM: Combining Explicit and Implicit Feature Interactions for Recommender Systems
#    Title: Active Feature Acquisition with Supervised Matrix Completion
#    Title: Prediction-time Efficient Classification Using Feature Computational Dependencies
# Keyword: anomali (Number of papers: 3)
#    Title: NetWalk: A Flexible Deep Embedding Approach for Anomaly Detection in Dynamic Networks
#    Title: Feedback-Guided Anomaly Discovery via Online Optimization
#    Title: Detecting Spacecraft Anomalies Using LSTMs and Nonparametric Dynamic Thresholding
# Keyword: dynam (Number of papers: 3)
#    Title: NetWalk: A Flexible Deep Embedding Approach for Anomaly Detection in Dynamic Networks
#    Title: Dynamic Embeddings for User Profiling in Twitter
#    Title: Learning and Interpreting Complex Distributions in Empirical Data
# Keyword: compress (Number of papers: 3)
#    Title: REST: A Reference-based Framework for Spatio-temporal Trajectory Compression
#    Title: Towards Evolutionary Compression
#    Title: Shield: Fast, Practical Defense and Vaccination for Deep Learning using JPEG Compression
# Keyword: weight (Number of papers: 3)
#    Title: Multiview Clustering via Adaptively Weighted Procrustes
#    Title: BagMinHash - Minwise Hashing Algorithm for Weighted Sets
#    Title: Scalable Optimization for Embedding Highly-Dynamic and Recency-Sensitive Data
# Keyword: node (Number of papers: 3)
#    Title: Deep Variational Network Embedding in Wasserstein Space
#    Title: Learning Structural Node Embeddings via Diffusion Wavelets
#    Title: Self-Paced Network Embedding
# Keyword: interpret (Number of papers: 3)
#    Title: Exact and Consistent Interpretation for Piecewise Linear Neural Networks: A Closed Form Solution
#    Title: Towards Explanation of DNN-based Prediction with Guided Feature Inversion
#    Title: On Interpretation of Network Embedding via Taxonomy Induction
# Keyword: attack (Number of papers: 3)
#    Title: Adversarial Attacks on Neural Networks for Graph Data
#    Title: Identify Susceptible Locations in Medical Records via Adversarial Attacks on Deep Predictive Models
#    Title: Shield: Fast, Practical Defense and Vaccination for Deep Learning using JPEG Compression
# Keyword: traffic (Number of papers: 3)
#    Title: IntelliLight: a Reinforcement Learning Approach for Intelligent Traffic Light Control
#    Title: Deep Sequence Learning with Auxiliary Information for Traffic Prediction
#    Title: Hetero-ConvLSTM: A Deep Learning Approach to Traffic Accident Prediction on Heterogeneous Spatio-Tem
# Keyword: tree (Number of papers: 3)
#    Title: Training Big Random Forests with Little Resources
#    Title: Extremely Fast Decision Tree
#    Title: RapidScorer: Fast Tree Ensemble Evaluation by Maximizing Compactness in Data Level Parallelization
# Keyword: cnn (Number of papers: 3)
#    Title: Towards Evolutionary Compression
#    Title: Estimating Glaucomatous Visual Sensitivity from Retinal Thickness by Using Pattern-Based Regularizat
#    Title: Rotation-Blended CNNs on a New Open Dataset for Tropical Cyclone Image-to-intensity Regression
# Keyword: price (Number of papers: 3)
#    Title: Deep Censored Learning of the Winning Price in the Real Time Bidding
#    Title: Customized Regression Model for Airbnb Dynamic Pricing
#    Title: Dynamic Pricing under Competition on Online Marketplaces: A Data-Driven Approach
# Keyword: mobil (Number of papers: 3)
#    Title: Not Just Privacy: Improving Performance of Private Deep Learning in Mobile Cloud
#    Title: Mobile access record resolution on large-scale identifier-linkage graphs
#    Title: StepDeep: A Novel Spatial-temporal Mobility Event Prediction Framework based on Deep Neural Network
# Keyword: water (Number of papers: 3)
#    Title: Using Machine Learning to Assess the Risk of and Prevent Water Main Breaks
#    Title: ActiveRemediation: The Search for Lead Pipes in Flint, Michigan
#    Title: State space models for forecasting water quality variables: An application in aquaculture prawn farm
# Keyword: park (Number of papers: 3)
#    Title: Du-Parking: Spatio-Temporal Big Data Tells You Realtime Parking Availability
#    Title: Detecting Illegal Vehicle Parking Events using Sharing Bikes’ Trajectories
#    Title: Where Will Dockless Shared Bikes be Stacked?—- Parking Hotspots Detection in a New City
# Keyword: notif (Number of papers: 3)
#    Title: Near real-time optimization of activity-based notifications
#    Title: PittGrub: A Frustration-Free System to Reduce Food Waste by Notifying Hungry College Students
#    Title: Notification Volume Control and Optimization System at Pinterest
# Keyword: campaign (Number of papers: 3)
#    Title: Audience Size Forecasting: Fast and Smart Budget Planning for Media Buyers
#    Title: Optimal Allocation of Real-Time-Bidding And Direct Campaigns
#    Title: Automated Audience Segmentation Using Reputation Signals
# Keyword: auction (Number of papers: 3)
#    Title: Optimization of a SSP’s Header Bidding Strategy using Thompson Sampling
#    Title: Optimal Allocation of Real-Time-Bidding And Direct Campaigns
#    Title: Deep Reinforcement Learning for Sponsored Search Real-time Bidding
# Keyword: event (Number of papers: 3)
#    Title: An Extensible Event Extraction System With Cross-Media Event Resolution
#    Title: EANN: Event Adversarial Neural Networks for Multi-Modal Fake News Detection
#    Title: StepDeep: A Novel Spatial-temporal Mobility Event Prediction Framework based on Deep Neural Network

# %%
# Gephi (GDF)
'''
nodedef>name VARCHAR,title VARCHAR,label VARCHAR,
1,title,article
2,title,article
3,title,tag
edgedef>node1 VARCHAR,node2 VARCHAR
1,2
2,3
3,2
3,1
'''

f = open( './graph/kdd2018.gdf', 'w', encoding='shift-jis', errors='ignore' )
# node
f.write( 'nodedef>name VARCHAR,tag VARCHAR,label VARCHAR,\n' )
### paper
for i, p in papers.items():
    f.write('%d,%s,%s,\n' % ( i, 'paper', p['title'].replace(' ', '_') ) )

### tag
widx = {}
idx = len( papers )
for w in papersWithSameKeyword.keys():
    f.write('%d,%s,%s,\n' % ( idx, 'keyword', w ) )
    widx[w] = idx
    idx += 1
    
# edge
f.write( 'edgedef>node1 VARCHAR,node2 VARCHAR\n' )
for w, pidxList in papersWithSameKeyword.items():
    for pidx in pidxList:
        f.write('%d,%d' % (widx[w], pidx) )
        f.write('\n')
f.close()

# %%
### Title Edge

# %%
from nltk.corpus import stopwords

stop_words = frozenset(stopwords.words('english'))

tf = {}
df = {}
for i, p in papers.items():
    title = p['title']
    title = title.lower()
    title = get_tokens( title, filteringPos )
    for w in title:
        if not w in tf: tf[w] = 0
        tf[w] += 1

# %%
for w, freq in sorted( tf.items(), key= lambda x:x[1], reverse=True ):
    print( w, freq )
# Out:
# learning 44
# deep 30
# network 24
# prediction 17
# detection 16
# search 14
# recommendation 13
# graph 12
# discovery 12
# dynamic 11
# online 11
# neural 10
# approach 10
# adversarial 9
# efficient 9
# optimization 9
# system 9
# framework 9
# scalable 8
# reinforcement 8
# information 8
# analysis 8
# large-scale 8
# time 8
# machine 8
# model 7
# active 7
# metric 7
# multi-task 6
# text 6
# representation 6
# extraction 6
# risk 6
# feature 6
# visual 6
# fast 6
# optimal 5
# adaptive 5
# heterogeneous 5
# hashing 5
# recurrent 5
# knowledge 5
# new 5
# recommender 5
# spatio-temporal 5
# user 5
# local 5
# product 5
# social 5
# behavior 4
# memory 4
# interactive 4
# semantic 4
# robust 4
# classification 4
# inference 4
# structural 4
# mechanism 4
# modeling 4
# regression 4
# estimation 4
# empirical 4
# attention 4
# mining 4
# application 4
# transfer 4
# effective 4
# embedding 4
# clustering 4
# interpretable 4
# taxonomy 4
# mobile 4
# latent 4
# big 4
# planning 4
# algorithm 4
# e-commerce 4
# real-time 4
# quality 4
# event 4
# proximity 3
# graphs 3
# error 3
# supervised 3
# semi-supervised 3
# gradient 3
# treatment 3
# unsupervised 3
# urban 3
# multi-label 3
# medical 3
# interpretation 3
# evaluation 3
# compression 3
# temporal 3
# collaborative 3
# random 3
# space 3
# tree 3
# private 3
# privacy 3
# traffic 3
# control 3
# sequential 3
# self-paced 3
# generative 3
# vehicle 3
# human 3
# multiple 3
# bidding 3
# case 3
# ’ 3
# s 3
# ranking 3
# query 3
# practical 3
# novel 3
# improved 2
# discrete 2
# policy 2
# joint 2
# similar 2
# unified 2
# content 2
# spotlight 2
# stock 2
# context 2
# co-attention 2
# decision 2
# brain 2
# image 2
# probabilistic 2
# opinion 2
# attribute 2
# region 2
# dual 2
# markov 2
# task 2
# problem 2
# complex 2
# multi-modal 2
# maximum 2
# pattern-based 2
# algorithms 2
# healthcare 2
# performance 2
# anomaly 2
# training 2
# cnns 2
# spectral 2
# cut 2
# unfairness 2
# variational 2
# hiring 2
# labor 2
# hierarchical 2
# linear 2
# solution 2
# concept 2
# equivalence 2
# descent 2
# budget 2
# acquisition 2
# matrix 2
# completion 2
# node 2
# engine 2
# explanation 2
# influence 2
# maximization 2
# causal 2
# binary 2
# series 2
# retrieval 2
# trading 2
# factorization 2
# method 2
# convolutional 2
# asymmetric 2
# rare 2
# characterization 2
# computer 2
# effect 2
# variable 2
# selection 2
# bayesian 2
# structure 2
# pairwise 2
# incremental 2
# value 2
# history 2
# billion-scale 2
# travel 2
# multimodal 2
# patient 2
# route 2
# customer 2
# hyperparameter 2
# vector 2
# predictive 2
# support 2
# forecasting 2
# expansion 2
# sentiment 2
# identification 2
# airbnb 2
# pricing 2
# alzheimer 2
# disease 2
# platform 2
# scale 2
# water 2
# rule-based 2
# open 2
# name 2
# rate 2
# recognition 2
# web-scale 2
# audience 2
# city 2
# alibaba 2
# fusion 2
# resolution 2
# data-driven 2
# modern 2
# speed 2
# malware 2
# study 2
# negative 2
# news 2
# matching 2
# linkedin 2
# dilated 1
# dense 1
# non-redundant 1
# trajectory-driven 1
# influential 1
# billboard 1
# placement 1
# multi-type 1
# itemset 1
# success 1
# stamp 1
# short-term 1
# attention/memory 1
# priority 1
# session-based 1
# crowd 1
# decayed 1
# approximated 1
# reduction 1
# r2sdh 1
# multi-view 1
# cross-domain 1
# distribution 1
# disturbance 1
# grassmann 1
# subspace-based 1
# stockassistant 1
# ai 1
# assistant 1
# reliability 1
# meta-path 1
# top 1
# n 1
# subspace 1
# censored 1
# neurodegenerative 1
# additional 1
# arbitrary-order 1
# lightweight 1
# voxel 1
# deconvolutional 1
# labeling 1
# count-min 1
# tight 1
# texttruth 1
# trustworthy 1
# multi-sourced 1
# heavyguardian 1
# separate 1
# guard 1
# hot 1
# predict 1
# edit 1
# survival 1
# susceptibility 1
# persuasion 1
# guarantee 1
# peer 1
# temporal-aware 1
# simultaneous 1
# function 1
# popularity 1
# infinite 1
# urbanization 1
# misosoup 1
# sampling 1
# pseudodimension 1
# netlsd 1
# shape 1
# fleet 1
# management 1
# multi-agent 1
# chain 1
# topic 1
# two-layer 1
# privacy-preserving 1
# truth 1
# sustain 1
# scoring 1
# sylvester 1
# equation 1
# solver 1
# tinet 1
# invariant 1
# multi-gate 1
# class-imbalance 1
# partial 1
# label 1
# region-of-interest 1
# map 1
# object 1
# multi-instance 1
# tr 1
# correntropy 1
# criterion 1
# truepie 1
# discovering 1
# reliable 1
# connectivity 1
# fundamental 1
# electronic 1
# prior 1
# distillation 1
# compact 1
# high 1
# xdeepfm 1
# combining 1
# explicit 1
# implicit 1
# netwalk 1
# flexible 1
# cost-effective 1
# adaptation 1
# offline 1
# click 1
# rest 1
# reference-based 1
# trajectory 1
# high-order 1
# factorial 1
# marked 1
# point 1
# r-vqa 1
# relation 1
# question 1
# incomplete 1
# detecting 1
# ultrahigh-dimensional 1
# distance-based 1
# profiling 1
# twitter 1
# algorithmic 1
# individual 1
# group 1
# vi 1
# multiview 1
# wasserstein 1
# geographical 1
# hidden 1
# flood 1
# extent 1
# mapping 1
# neighborhood 1
# formation 1
# outsourcing 1
# market 1
# diff 1
# executable 1
# aware 1
# exact 1
# consistent 1
# piecewise 1
# closed 1
# form 1
# taxogen 1
# topical 1
# term 1
# recursive 1
# regular 1
# pca 1
# determinant 1
# spurious 1
# optima 1
# uncovering 1
# conceptual 1
# biomedical 1
# evolution 1
# per-iteration 1
# submodular 1
# stable 1
# unknown 1
# feedback-guided 1
# similarity 1
# q-grams 1
# real-world 1
# multi-pointer 1
# binning 1
# model-based 1
# short 1
# next-period 1
# intellilight 1
# intelligent 1
# light 1
# dnn-based 1
# guided 1
# inversion 1
# multi-round 1
# score 1
# xiaoice 1
# band 1
# melody 1
# arrangement 1
# generation 1
# pop 1
# music 1
# r-th 1
# root 1
# rank 1
# multivariate 1
# detector 1
# bike 1
# reposition 1
# multi-user 1
# parallel 1
# paradigm 1
# top-n 1
# investor-imitator 1
# ranking-based 1
# larc 1
# activity-regularized 1
# evograph 1
# little 1
# learnable 1
# imbalanced 1
# multi-modality 1
# sparc 1
# few-shot 1
# category 1
# evolutionary 1
# accurate 1
# locality-sensitive 1
# scheme 1
# inner 1
# qa 1
# asynchronous 1
# two-view 1
# discontinuity 1
# design 1
# pme 1
# link 1
# self-translation 1
# isolation 1
# svm 1
# grouping 1
# uncertainty 1
# discrete-continuous 1
# significant 1
# permutation 1
# induction 1
# comprehensive 1
# transcription 1
# structured 1
# aggregate 1
# present 1
# next-item 1
# beh 1
# kernel 1
# stein 1
# gpu-enabled 1
# exhaustive 1
# dilof 1
# diffusion 1
# isomorphism 1
# demand-aware 1
# charger 1
# electric 1
# safe 1
# triplet 1
# distance 1
# follow-the-regularized-leader 1
# chit-chat 1
# learning-to-ask 1
# multi-cast 1
# context-aware 1
# academic 1
# collaborator 1
# raim 1
# attentive 1
# intensive 1
# continuous 1
# monitoring 1
# idle 1
# taxi 1
# importance 1
# classifying 1
# contexts 1
# multilevel 1
# wavelet 1
# decomposition 1
# presence 1
# gaussian 1
# process 1
# calcul 1
# winning 1
# price 1
# real 1
# cluster-based 1
# randomized 1
# monotonicity 1
# credible 1
# post 1
# hoc 1
# interpretability 1
# factor 1
# conflict 1
# distributed 1
# quasi-newton 1
# minimization 1
# regularization 1
# deepinf 1
# iterative 1
# global 1
# structure-assisted 1
# aligner 1
# behavioral 1
# imaging 1
# discrimination 1
# removal 1
# ranked 1
# fairness 1
# exposure 1
# minwise 1
# weighted 1
# nested 1
# spatial 1
# group-level 1
# disaggregation 1
# d2k 1
# community 1
# massive 1
# small-diameter 1
# butterfly 1
# counting 1
# bipartite 1
# numerical 1
# algebra 1
# multi-output 1
# blood 1
# glucose 1
# building 1
# trafficking 1
# improving 1
# cloud 1
# xstream 1
# feature-evolving 1
# gene 1
# expression 1
# hiexpan 1
# task-guided 1
# construction 1
# prediction-time 1
# computational 1
# spectrum 1
# holistic 1
# time-varying 1
# environment 1
# i 1
# ll 1
# churn 1
# app 1
# prepep 1
# tool 1
# interference 1
# order 1
# dispatch 1
# on-demand 1
# ride-sharing 1
# watthome 1
# identifying 1
# energy-inefficient 1
# city-scale 1
# perceive 1
# depth 1
# universal 1
# e-tail 1
# return 1
# hypergraph-based 1
# tatc 1
# actigraphy 1
# automatic 1
# soccer 1
# match 1
# corpus 1
# conversion 1
# service 1
# prevent 1
# main 1
# weak 1
# chemnet 1
# transferable 1
# chemical 1
# property 1
# p 1
# opentag 1
# spacecraft 1
# lstms 1
# nonparametric 1
# thresholding 1
# parameter 1
# web-based 1
# advertising 1
# video 1
# understanding 1
# disambiguation 1
# aminer 1
# maintenance 1
# loop 1
# false 1
# exper 1
# rosetta 1
# large 1
# glaucomatous 1
# sensitivity 1
# retinal 1
# thickness 1
# regularizat 1
# aviation 1
# safety 1
# instance 1
# station-level 1
# demand 1
# rebalancing 1
# bike-sharing 1
# du-parking 1
# availability 1
# activity-based 1
# prototype-based 1
# drug 1
# conditional 1
# diversity 1
# ehealth 1
# wild 1
# sphere 1
# project 1
# personalization 1
# illegal 1
# size 1
# smart 1
# q 1
# r 1
# two-stage 1
# activeremediation 1
# lead 1
# flint 1
# michigan 1
# winner 1
# curse 1
# bias 1
# total 1
# apathy 1
# behaviour 1
# rnns 1
# pipeline 1
# fire 1
# ssp 1
# header 1
# strategy 1
# thompson 1
# delta 1
# guide 1
# —- 1
# hotspots 1
# air 1
# interest 1
# click-through 1
# tree-based 1
# extensible 1
# cross-media 1
# competition 1
# pittgrub 1
# frustration-free 1
# food 1
# waste 1
# hungry 1
# college 1
# autotune 1
# derivative-free 1
# tuning 1
# box 1
# office 1
# result 1
# consumer-centric 1
# state 1
# aquaculture 1
# prawn 1
# farm 1
# employer 1
# normalization 1
# o 1
# responsive 1
# ant 1
# financial 1
# formalization 1
# next-step 1
# cota 1
# accuracy 1
# device 1
# graphing 1
# example 1
# sdregion 1
# spotting 1
# biological 1
# rapidscorer 1
# ensemble 1
# compactness 1
# level 1
# parallelization 1
# efficiency 1
# codebase 1
# scorpion 1
# metagraph2vec 1
# career 1
# fatigue 1
# outdoor 1
# sensor 1
# metapopulation 1
# propagation 1
# intra-city 1
# epidemic 1
# prevention 1
# bigin4 1
# instant 1
# insight 1
# multi-dimensional 1
# computer-assisted 1
# inhibi 1
# commodity 1
# voice 1
# entertainment 1
# three-layer 1
# split 1
# delivery 1
# container 1
# loa 1
# estimated 1
# arrival 1
# commercial 1
# sqr 1
# balancing 1
# allocation 1
# real-time-bidding 1
# direct 1
# tax 1
# fraud 1
# under-reporting 1
# candidate 1
# preference 1
# web 1
# browsing 1
# feedback 1
# characterisation 1
# personalisation 1
# unstructured 1
# part-of-speech 1
# tagging 1
# hardware 1
# repeat 1
# purchase 1
# paywall 1
# digital 1
# sequence 1
# auxiliary 1
# n-gram 1
# relevance 1
# sponsored 1
# highly-dynamic 1
# recency-sensitive 1
# pangloss 1
# entity 1
# noisy 1
# anatomy 1
# privacy-safe 1
# email 1
# student 1
# check-in 1
# point-of-interest 1
# eann 1
# fake 1
# progression 1
# notification 1
# volume 1
# pinterest 1
# kaggle 1
# susceptible 1
# shield 1
# defense 1
# vaccination 1
# jpeg 1
# public 1
# paroxysmal 1
# atrial 1
# fibrillation 1
# bidirectional 1
# net 1
# noise 1
# abstract 1
# conversational 1
# hierarchically-stacked 1
# rnn 1
# access 1
# record 1
# identifier-linkage 1
# vatican 1
# secret 1
# codice 1
# ratio 1
# economic 1
# salary 1
# hetero-convlstm 1
# accident 1
# spatio-tem 1
# segmentation 1
# reputation 1
# infrastructure 1
# assessment 1
# africa 1
# satellite 1
# imagery 1
# nguard 1
# game 1
# bot 1
# netease 1
# mmorpgs 1
# rotation-blended 1
# dataset 1
# tropical 1
# cyclone 1
# image-to-intensity 1
# high-performance 1
# mix 1
# multi-channel 1
# cultural 1
# wechat 1
# multitask 1
# heterogenous 1
# icu 1
# stepdeep 1
# spatial-temporal 1
# mobility 1

# %%
### Author Edge

# %%
# get scrapbox format
import json
from pprint import pprint

# %%
f = open( 'kdd2018.json', 'r' )
j = json.load( f )

# %%
for i, paper in papers.items():
    page = {}
    page['title'] = paper['title']

    page['lines'] = []
    page['lines'].append( paper['title'] )

    page['lines'].append( '' )   
    aut = ''
    for a in paper['author']:
        a = a.replace(' ', '_')
        aut += '#%s; ' % a
    page['lines'].append( aut )
    
    page['lines'].append( '' )
    page['lines'].append( paper['abst'] )

    if paper['yid'] == 'None':
        page['lines'].append( '' )
        page['lines'].append( 'The video does not exist' )    
    else:
        page['lines'].append( '' )
        page['lines'].append( '[https://www.youtube.com/watch?v=%s]' % paper['yid'] )    
    
    if paper['pdf'] == 'None':
        page['lines'].append( '' )
        page['lines'].append( 'The PDF does not exist' )  
    else:
        page['lines'].append( '' )
        page['lines'].append( 'PDF url: %s' % paper['pdf'] )
    
    j['pages'].append( page )

# %%
fw = open( 'kdd2018_.json', 'w' )
json.dump( j, fw, indent=4 )
